# %% [markdown]
# <a href="https://colab.research.google.com/github/marcarvajalma/MetNumUN2024II/blob/main/Lab5/LAB_ATQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Laboratorio Quantiacs
# ## Maria Paula Carvajal

# %% [markdown]
# ##Gráfica

# %% [markdown]
# ![imagen1.png](data:image/png;base64,...)

# %% [markdown]
# ## Sharpe Ratio

# %% [markdown]
# ![imagen2.png](data:image/png;base64,...)

# %% [markdown]
# ## Gaussian Naive Bayes
#
# El **Gaussian Naive Bayes** es un modelo sencillo y eficiente, perfecto para tareas de clasificación donde se necesita rapidez. Se adapta muy bien a datos que tienen una distribución normal y ofrece buenos resultados incluso con conjuntos de datos pequeños. Además, como utiliza probabilidades, es fácil de interpretar, lo que lo convierte en una excelente opción para problemas como predecir movimientos de precios en tiempo real.

# %% [markdown]
# https://scikit-learn.org/stable/modules/naive_bayes.html

# %% [markdown]
# https://builtin.com/artificial-intelligence/gaussian-naive-bayes

# %% [markdown]
# ## Variable agregada

# %% [markdown]
# El **On Balance Volume (OBV)** es un indicador que mide el flujo de volumen acumulado en relación con los cambios de precio, basándose en la idea de que los movimientos de volumen preceden a los de precio. Si el precio cierra más alto que el día anterior, el volumen se suma al OBV; si cierra más bajo, se descarta; y si no cambia, el OBV permanece igual. Un OBV creciente indica una tendencia alcista, mientras que un OBV decreciente sugiere una tendencia bajista. Además, si el precio sube pero el OBV no lo sigue, puede señalar que la tendencia está perdiendo fuerza y que una reversión podría estar cerca.

# %% [markdown]
# https://quantiacs.com/documentation/en/user_guide/technical_indicators.html
